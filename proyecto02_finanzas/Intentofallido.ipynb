# %%
import urllib.request 
from pprint import pprint 
from html_table_parser import HTMLTableParser 
import pandas as pd 
import requests

# %%
def url_get_contents(url):  
    
    req = urllib.request.Request(url=url) 
    f = urllib.request.urlopen(req)  
    return f.read() 
  
xhtml = url_get_contents('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies').decode('utf-8') 
  
p = HTMLTableParser() 
  
p.feed(xhtml) 
  
pprint(p.tables[1]) 
  
print("\n\nPANDAS DATAFRAME\n") 
print(pd.DataFrame(p.tables[1]))
# Out:
# [['Date', 'Added', 'Removed', 'Reason'],
#  ['Ticker', 'Security', 'Ticker', 'Security'],
#  ['June 21, 2022',
#   'KDP',
#   'Keurig Dr Pepper',
#   'UA/UAA',
#   'Under Armour',
#   'Market capitalization change. 5'],
#  ['June 21, 2022',
#   'ON',
#   'ON Semiconductor',
#   'IPGP',
#   'IPG Photonics',
#   'Market capitalization change. 5'],
#  ['June 8, 2022',
#   'VICI',
#   'Vici Properties',
#   'CERN',
#   'Cerner',
#   'S P 500 constituent Oracle Corp. acquired Cerner. 5'],
#  ['April 4, 2022',
#   'CPT',
#   'Camden Property Trust',
#   'PBCT',
#   "People's United Financial",
#   'S P 500 constituent M T Bank Corp. acquired People’s United Financial. 6'],
#  ['March 2, 2022',
#   'MOH',
#   'Molina Healthcare',
#   'INFO',
#   'IHS Markit',
#   'S P 500 constituent S P Global Inc. acquired IHS Markit. 7'],
#  ['February 15, 2022',
#   'NDSN',
#   'Nordson Corporation',
#   'XLNX',
#   'Xilinx',
#   'S P 500 constituent Advanced Micro Devices acquired Xilinx. 8'],
# ...

# %%
df_500_wiki=pd.DataFrame(p.tables[-1])
df_500_wiki.head(10)
# Out:
#                    0         1                      2         3  \
# 0               Date     Added                Removed    Reason
# 1             Ticker  Security                 Ticker  Security
# 2      June 21, 2022       KDP       Keurig Dr Pepper    UA/UAA
# 3      June 21, 2022        ON       ON Semiconductor      IPGP
# 4       June 8, 2022      VICI        Vici Properties      CERN
# 5      April 4, 2022       CPT  Camden Property Trust      PBCT
# 6      March 2, 2022       MOH      Molina Healthcare      INFO
# 7  February 15, 2022      NDSN    Nordson Corporation      XLNX
# 8   February 3, 2022                                        GPS
# 9   February 2, 2022       CEG   Constellation Energy
#
#                            4  \
# 0                       None
# 1                       None
# 2               Under Armour
# 3              IPG Photonics
# 4                     Cerner
# 5  People's United Financial
# 6                 IHS Markit
# ...

# %%
import pandas as pd
data = pd.read_html(https://en.wikipedia.org/wiki/List_of_S%26P_500_companies, decimal=',')
# Out:
#   Input In [13]
#     data = pd.read_html(https://en.wikipedia.org/wiki/List_of_S%26P_500_companies, decimal=',')
#                                                                  ^
# SyntaxError: invalid decimal literal

# %%
url='https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
pagina=requests.get(url).content
df_list=pd.read_html(pagina)
df=df_list[-1]
df.head(5)
# Out:
#             Date  Added                        Removed  \
#             Date Ticker               Security  Ticker
# 0  June 21, 2022    KDP       Keurig Dr Pepper  UA/UAA
# 1  June 21, 2022     ON       ON Semiconductor    IPGP
# 2   June 8, 2022   VICI        Vici Properties    CERN
# 3  April 4, 2022    CPT  Camden Property Trust    PBCT
# 4  March 2, 2022    MOH      Molina Healthcare    INFO
#
#                               \
#                     Security
# 0               Under Armour
# 1              IPG Photonics
# 2                     Cerner
# 3  People's United Financial
# 4                 IHS Markit
#
#                                               Reason
#                                               Reason
# 0                   Market capitalization change.[5]
# 1                   Market capitalization change.[5]
# 2  S&P 500 constituent Oracle Corp. acquired Cern...
# 3  S&P 500 constituent M&T Bank Corp. acquired Pe...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   (Date, Date)         302 non-null    object
#  1   (Added, Ticker)      296 non-null    object
#  2   (Added, Security)    296 non-null    object
#  3   (Removed, Ticker)    290 non-null    object
#  4   (Removed, Security)  290 non-null    object
#  5   (Reason, Reason)     302 non-null    object
# dtypes: object(6)
# memory usage: 14.3+ KB
